# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3,4,5]
y = [10,30,50,40,70]
plt.plot(x,y)
plt.title("test")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
